# %%
import yfinance as yf
spy = yf.Ticker("SPY")
data = spy.option_chain('2020-09-02') # get option chain for specific expiration

# %%
type(data)
# Out:
# yfinance.ticker.Options

# %%
data
# Out:
# Options(calls=        contractSymbol       lastTradeDate  strike  lastPrice     bid     ask  \
# 0   SPY200902C00200000 2020-08-06 16:26:59   200.0     132.11  150.17  150.71
# 1   SPY200902C00225000 2020-08-26 13:51:11   225.0     119.62  125.17  125.71
# 2   SPY200902C00270000 2020-08-28 14:13:31   270.0      78.78   80.19   80.72
# 3   SPY200902C00280000 2020-08-10 13:42:54   280.0      55.72   70.19   70.72
# 4   SPY200902C00290000 2020-08-28 19:11:32   290.0      60.20   60.21   60.68
# ..                 ...                 ...     ...        ...     ...     ...
# 80  SPY200902C00385000 2020-08-27 19:31:55   385.0       0.02    0.00    0.01
# 81  SPY200902C00390000 2020-08-27 15:12:50   390.0       0.01    0.00    0.01
# 82  SPY200902C00395000 2020-08-28 17:27:04   395.0       0.01    0.00    0.01
# 83  SPY200902C00400000 2020-08-17 04:02:43   400.0       0.01     NaN    0.01
# 84  SPY200902C00410000 2020-08-27 15:44:13   410.0       0.01     NaN    0.01
#
# ...

# %%
data.calls
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice     bid     ask  \
# 0   SPY200902C00200000 2020-08-06 16:26:59   200.0     132.11  150.17  150.71
# 1   SPY200902C00225000 2020-08-26 13:51:11   225.0     119.62  125.17  125.71
# 2   SPY200902C00270000 2020-08-28 14:13:31   270.0      78.78   80.19   80.72
# 3   SPY200902C00280000 2020-08-10 13:42:54   280.0      55.72   70.19   70.72
# 4   SPY200902C00290000 2020-08-28 19:11:32   290.0      60.20   60.21   60.68
# ..                 ...                 ...     ...        ...     ...     ...
# 80  SPY200902C00385000 2020-08-27 19:31:55   385.0       0.02    0.00    0.01
# 81  SPY200902C00390000 2020-08-27 15:12:50   390.0       0.01    0.00    0.01
# 82  SPY200902C00395000 2020-08-28 17:27:04   395.0       0.01    0.00    0.01
# 83  SPY200902C00400000 2020-08-17 04:02:43   400.0       0.01     NaN    0.01
# 84  SPY200902C00410000 2020-08-27 15:44:13   410.0       0.01     NaN    0.01
#
# ...

# %%
data.puts
# Out:
#         contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0   SPY200902P00165000 2020-08-10 17:13:51   165.0       0.02   0.00   0.01
# 1   SPY200902P00170000 2020-08-07 17:41:34   170.0       0.02   0.00   0.01
# 2   SPY200902P00175000 2020-08-17 04:03:12   175.0       0.01   0.00   0.01
# 3   SPY200902P00180000 2020-08-17 18:21:58   180.0       0.01   0.00   0.01
# 4   SPY200902P00185000 2020-08-14 19:01:15   185.0       0.01   0.00   0.01
# ..                 ...                 ...     ...        ...    ...    ...
# 87  SPY200902P00357000 2020-08-27 16:19:20   357.0       6.71   6.60   6.99
# 88  SPY200902P00359000 2020-08-28 19:21:40   359.0       8.55   8.48   8.89
# 89  SPY200902P00360000 2020-08-28 15:54:36   360.0      10.83   9.44   9.86
# 90  SPY200902P00370000 2020-08-24 13:30:43   370.0      27.91  19.36  19.79
# 91  SPY200902P00395000 2020-08-06 16:26:59   395.0      62.93  44.36  44.81
#
# ...

# %%
data.calls[['lastPrice','strike']].plot(x='strike',
                                        y='lastPrice',
                                        label='SPY Call 2020-09-02')

# %%
data.puts[['lastPrice','strike']].plot(x='strike',
                                       y='lastPrice',
                                       label='SPY Put 2020-09-02')
