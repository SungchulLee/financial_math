# %%
import pandas as pd
data = pd.read_csv('../data/etf/spy.csv', parse_dates=True, index_col=0)

# %%
cols = ['Open','High','Low','Close']
data.loc["2017-01-01":"2017-01-10", cols].plot(title='SPY')
