# %% [markdown]
# # GMVP
#
# Sungchul Lee

# %% [markdown]
# # References
#
# Interest Rate Risk Modeling [local](http://localhost:8888/notebooks/Dropbox/Paper/그Interest Rate Risk Modeling.pdf)
#
# Applied Quantitative Finance [local - 1st edition](http://localhost:8888/notebooks/Dropbox/Paper/Applied Quantitative Finance.pdf) [local - 2nd edition](http://localhost:8888/notebooks/Dropbox/Paper/Applied Quantitative Finance  Second Edition.pdf)
#
# Paul Wilmott On Quantitative Finance [local - Volume 1](http://localhost:8888/notebooks/Dropbox/Paper/Paul Wilmott On Quantitative Finance Volume 1.pdf) [local - Volume 2](http://localhost:8888/notebooks/Dropbox/Paper/paul wilmott on quantitative fiance volume 2.pdf) [local - Volume 3](http://localhost:8888/notebooks/Dropbox/Paper/Paul Wilmott On Quantitative Finance Volume 3.pdf)
#
# 금융수학 입문 [local](http://localhost:8888/notebooks/Dropbox/Paper/금융수학 입문.pdf)
#
# 금융수학 [local](http://localhost:8888/notebooks/Dropbox/Paper/금융수학.pdf)
#
# 금융수학과 투자전략의 이해 [local](http://localhost:8888/notebooks/Dropbox/Paper/금융수학과 투자전략의 이해.pdf)
#
#
# R을 활용한 금융 데이터  마이닝 [조성현 - local](http://localhost:8888/notebooks/Dropbox/Paper/Financial_Data_Mining.pdf)
#
# Dark Pools and High Frequency Trading For Dummies  [Jay Vaananen - local](http://localhost:8888/notebooks/Dropbox/Paper/Dark Pools and High Frequency Trading For Dummies.pdf)
#
# Statistical arbitrage_ Algorithmic trading insights and techniques  [Andrew Pole - local](http://localhost:8888/notebooks/Dropbox/Paper/Statistical arbitrage_ Algorithmic trading insights and techniques.pdf)
#
# Options, Futures, and Other Derivatives-Prentice Hall [John C. Hull - local](http://localhost:8888/notebooks/Dropbox/Paper/John C. Hull-Options, Futures, and Other Derivatives-Prentice Hall.pdf)
#
# Numerical Methods in Finance & Economics A MATLAB based Introduction [Paolo Brandimarte - local](http://localhost:8888/notebooks/Dropbox/Paper/Numerical Methods in Finance & Economics A MATLAB based Introduction - Paolo Brandimarte.pdf)
#
# Derman's Lectures on Local Volatility  [local](http://localhost:8888/notebooks/Dropbox/Paper/Derman's Lectures on Local Volatility.pdf)
#
# Interest Rate Modeling [local - Volume 1](http://localhost:8888/notebooks/Dropbox/Paper/Interest_Rate_Modeling 1Interest_Rate_Modeling 1.pdf) [local - Volume 2](http://localhost:8888/notebooks/Dropbox/Paper/Interest_Rate_Modeling 2.pdf) [local - Volume 3](http://localhost:8888/notebooks/Dropbox/Paper/Interest_Rate_Modeling 3.pdf)
#
# Interest Rate Models Theory and  Practice [local](http://localhost:8888/notebooks/Dropbox/Paper/그Interest Rate Models Theory and  Practice.pdf)
#
# Interest Rate Models.Theory & Practice.With Smile,Inflation & Credit [local](http://localhost:8888/notebooks/Dropbox/Paper/Interest Rate Models.Theory & Practice.With Smile,Inflation & Credit.pdf)
#
# Interest Rate Option Models [local](http://localhost:8888/notebooks/Dropbox/Paper/그Interest Rate Option Models.pdf)
#
# Interest Rate Risk Modeling [local](http://localhost:8888/notebooks/Dropbox/Paper/그Interest Rate Risk Modeling.pdf)

# %% [markdown]
# # How to run these slides yourself
#
# **Setup python environment**
#
# - [Install RISE for an interactive presentation viewer](https://github.com/damianavila/RISE)

# %% [markdown]
# Application of neural networks to an emerging financial market forecasting and trading the Taiwan Stock Index [local](http://localhost:8888/notebooks/Dropbox/Paper/Application of neural networks to an emerging financial market forecasting and trading the Taiwan Stock Index.pdf)
#
# Application of support vector machines in financial time series forecasting [local](http://localhost:8888/notebooks/Dropbox/Paper/Application of support vector machines in financial time series forecasting.pdf)
#
# Consumer credit-risk models via machine-learning algorithms [local](http://localhost:8888/notebooks/Dropbox/Paper/Consumer credit-risk models via machine-learning algorithms.pdf)
#
# Credit default swap pricing using artificial neural networks [local](http://localhost:8888/notebooks/Dropbox/Paper/Credit default swap pricing using artificial neural networks.pdf)
#
# Financial forecasting using support vector machines [local](http://localhost:8888/notebooks/Dropbox/Paper/Financial forecasting using support vector machines.pdf)
#
# Financial time series forecasting using support vector machines [local](http://localhost:8888/notebooks/Dropbox/Paper/Financial time series forecasting using support vector machines.pdf)
#
# Financial time series prediction using least squares support vector machines within the evidence framework [local](http://localhost:8888/notebooks/Dropbox/Paper/Financial time series prediction using least squares support vector machines within the evidence framework.pdf)
#
# Forecasting with artificial neural networks; the state of the art [local](http://localhost:8888/notebooks/Dropbox/Paper/Forecasting with artificial neural networks; the state of the art.pdf)
#
# Improving returns on stock investment through neural network selection [local](http://localhost:8888/notebooks/Dropbox/Paper/Improving returns on stock investment through neural network selection.pdf)
#
# Predicting credit default swap prices with financial and pure data-driven approaches [local](http://localhost:8888/notebooks/Dropbox/Paper/Predicting credit default swap prices with financial and pure data-driven approaches.pdf)
#
# Stock price pattern recognition - A recurrent neural network approach [local](http://localhost:8888/notebooks/Dropbox/Paper/Stock price pattern recognition - A recurrent neural network approach.pdf)
#
# Support vector machine with adaptive parameters in financial time series forecasting [local](http://localhost:8888/notebooks/Dropbox/Paper/Support vector machine with adaptive parameters in financial time series forecasting.pdf)
#
# A first-passage-time model under regime-switching market environment [local](http://localhost:8888/notebooks/Dropbox/Paper/A first-passage-time model under regime-switching market environment.pdf)
#
# A simple iterative method for the valuation of American options [local](http://localhost:8888/notebooks/Dropbox/Paper/A simple iterative method for the valuation of American options.pdf)
#
# An algorithm for optimal portfolio selection problem with transaction costs and random lifetimes [local](http://localhost:8888/notebooks/Dropbox/Paper/An algorithm for optimal portfolio selection problem with transaction costs and random lifetimes.pdf)
#
# Analytic valuation formulas for range notes and an affine term structure model with jump risks [local](http://localhost:8888/notebooks/Dropbox/Paper/Analytic valuation formulas for range notes and an affine term structure model with jump risks.pdf)
#
# Areflected diffusion process in a regime-switching environment [local](http://localhost:8888/notebooks/Dropbox/Paper/Areflected diffusion process in a regime-switching environment.pdf)
#
# Liquidity Premia and Transaction Costs [local](http://localhost:8888/notebooks/Dropbox/Paper/Liquidity Premia and Transaction Costs.pdf)
#
# OPTIMAL PORTFOLIO SELECTION WITH TRANSACTION COSTS WHEN AN ILLIQUID ASSET PAYS CASHDIVIDENDS [local](http://localhost:8888/notebooks/Dropbox/Paper/OPTIMAL PORTFOLIO SELECTION WITH TRANSACTION COSTS WHEN AN ILLIQUID ASSET PAYS CASHDIVIDENDS.pdf)
#
# Optimal retirement strategy with a negative wealth constraint [local](http://localhost:8888/notebooks/Dropbox/Paper/Optimal retirement strategy with a negative wealth constraint.pdf)
#
# Optimal retirement with unemployment risks [local](http://localhost:8888/notebooks/Dropbox/Paper/Optimal retirement with unemployment risks.pdf)
#
# PSYCHOLOGICAL BARRIERS AND OPTION PRICING [local](http://localhost:8888/notebooks/Dropbox/Paper/PSYCHOLOGICAL BARRIERS AND OPTION PRICING.pdf)
#
# Stock Returns and Market Making with Inventory [local](http://localhost:8888/notebooks/Dropbox/Paper/Stock Returns and Market Making with Inventory.pdf)
#
# When Do the Unemployed Jump in the Workforce [local](http://localhost:8888/notebooks/Dropbox/Paper/When Do the Unemployed Jump in the Workforce.pdf)
#
# 경기주기와 베이지안 학습기번을 고려한 개인의 자산관리 연구 [local](http://localhost:8888/notebooks/Dropbox/Paper/경기주기와 베이지안 학습기번을 고려한 개인의 자산관리 연구.pdf)
#
# 국내 파생결합증권의 가치평가 [local](http://localhost:8888/notebooks/Dropbox/Paper/국내 파생결합증권의 가치평가.pdf)
#
# 마코프 국면전환을 고려한 이자율 기간구조 연구 [local](http://localhost:8888/notebooks/Dropbox/Paper/마코프 국면전환을 고려한 이자율 기간구조 연구.pdf)
#
# 한국시장에서의 이자율 스왑 스프레드 결정 요인 연구 [local](http://localhost:8888/notebooks/Dropbox/Paper/한국시장에서의 이자율 스왑 스프레드 결정 요인 연구.pdf)
#
# A case-based reasoning system with the two-dimensional reduction technique for customer classification [local](http://localhost:8888/notebooks/Dropbox/Paper/A case-based reasoning system with the two-dimensional reduction technique for customer classification.pdf)
#
# A recommender system using GA K-means clustering in an online shopping market [local](http://localhost:8888/notebooks/Dropbox/Paper/A recommender system using GA K-means clustering in an online shopping market.pdf)
#
# Artificial neural networks with evolutionary instance selection for financial forecasting [local](http://localhost:8888/notebooks/Dropbox/Paper/Artificial neural networks with evolutionary instance selection for financial forecasting.pdf)
#
# Bankruptcy prediction modeling with hybrid case-based reasoning and genetic algorithms approach [local](http://localhost:8888/notebooks/Dropbox/Paper/Bankruptcy prediction modeling with hybrid case-based reasoning and genetic algorithms approach.pdf)
#
# Factors affecting the implementation success of Internet-based information systems [local](http://localhost:8888/notebooks/Dropbox/Paper/Factors affecting the implementation success of Internet-based information systems.pdf)
#
# Financial time series forecasting using support vector machines [local](http://localhost:8888/notebooks/Dropbox/Paper/Financial time series forecasting using support vector machines.pdf)
#
# Global optimization of case-based reasoning for breast cytology diagnosis [local](http://localhost:8888/notebooks/Dropbox/Paper/Global optimization of case-based reasoning for breast cytology diagnosis.pdf)
#
# Global optimization of feature weights and the number of neighbors that combine in a case-based reasoning system [local](http://localhost:8888/notebooks/Dropbox/Paper/Global optimization of feature weights and the number of neighbors that combine in a case-based reasoning system.pdf)
#
#
# Global optimization of support vector machines using genetic algorithms for bankruptcy prediction [local](http://localhost:8888/notebooks/Dropbox/Paper/Global optimization of support vector machines using genetic algorithms for bankruptcy prediction.pdf)
#
# Hybrid genetic algorithms and case-based reasoning systems for customer classification [local](http://localhost:8888/notebooks/Dropbox/Paper/Hybrid genetic algorithms and case-based reasoning systems for customer classification.pdf)
#
# Hybrid genetic algorithms and case-based reasoning systems [local](http://localhost:8888/notebooks/Dropbox/Paper/Hybrid genetic algorithms and case-based reasoning systems.pdf)
#
# Simultaneous optimization of artificial neural networks for financial forecasting [local](http://localhost:8888/notebooks/Dropbox/Paper/Simultaneous optimization of artificial neural networks for financial forecasting.pdf)
#
# Stock market prediction using artificial neural networks with optimal feature transformation [local](http://localhost:8888/notebooks/Dropbox/Paper/Stock market prediction using artificial neural networks with optimal feature transformation.pdf)
#
# Toward global optimization of case-based reasoning systems for financial forecasting [local](http://localhost:8888/notebooks/Dropbox/Paper/Toward global optimization of case-based reasoning systems for financial forecasting.pdf)
#
# Using a clustering genetic algorithm to support customer segmentation for personalized recommender systems [local](http://localhost:8888/notebooks/Dropbox/Paper/Using a clustering genetic algorithm to support customer segmentation for personalized recommender systems.pdf)
#
# Using case-based reasoning for the design of controls for internet-based information systems [local](http://localhost:8888/notebooks/Dropbox/Paper/Using case-based reasoning for the design of controls for internet-based information systems.pdf)
#
#
# Using genetic algorithms to optimize nearest neighbors for data mining [local](http://localhost:8888/notebooks/Dropbox/Paper/Using genetic algorithms to optimize nearest neighbors for data mining.pdf)
#
# A corporate credit rating model using multi-class support vector machines with an ordinal pairwise partitioning approach [local](http://localhost:8888/notebooks/Dropbox/Paper/A corporate credit rating model using multi-class support vector machines with an ordinal pairwise partitioning approach.pdf)
#
# Asset portfolio optimization using support vector machines and real-coded genetic algorithm [local](http://localhost:8888/notebooks/Dropbox/Paper/Asset portfolio optimization using support vector machines and real-coded genetic algorithm.pdf)
#
# Constructing investment strategy portfolios by combination genetic algorithms [local](http://localhost:8888/notebooks/Dropbox/Paper/Constructing investment strategy portfolios by combination genetic algorithms.pdf)
