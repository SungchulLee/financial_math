# %%
import pandas as pd
df_close = pd.read_csv('../data/sp500/Close.csv', 
                       index_col='Date', 
                       parse_dates=True)
df_close.tail()
# Out:
#                MMM     ABT   ABBV    ABMD     ACN   ATVI    ADBE    AMD  \
# Date
# 2020-08-20  161.50  101.63  95.20  310.01  236.61  84.00  478.48  82.77
# 2020-08-21  161.71  102.40  94.86  307.57  237.49  83.21  473.22  83.81
# 2020-08-24  163.53  101.39  94.51  304.95  237.75  83.10  476.30  83.08
# 2020-08-25  163.10  102.47  94.06  311.12  238.21  83.62  484.43  86.35
# 2020-08-26  163.90  103.19  94.35  306.14  240.45  84.48  528.49  86.02
#
#                AAP    AES  ...   WYNN    XEL    XRX    XLNX    XYL    YUM  \
# Date                       ...
# 2020-08-20  157.44  17.95  ...  80.28  69.01  18.75  101.38  79.13  94.91
# 2020-08-21  156.11  18.02  ...  82.79  69.61  18.76  102.00  79.14  95.63
# 2020-08-24  157.14  18.07  ...  86.79  70.41  19.30  102.47  81.14  96.09
# 2020-08-25  156.06  17.89  ...  86.21  68.97  18.91  103.39  80.68  96.48
# 2020-08-26  156.48  17.73  ...  84.80  68.13  18.79  104.98  80.70  95.33
#
#               ZBRA     ZBH   ZION     ZTS
# ...

# %% [markdown]
# $$
# \frac{S_t-S_{t-1}}{S_{t-1}}
# $$

# %%
df_pct_change = df_close.pct_change()
df_pct_change.to_csv('../data/sp500/Pct_Change.csv')
df_pct_change = pd.read_csv('../data/sp500/Pct_Change.csv', index_col='Date', parse_dates=True)

# %%
df_pct_change.head()
# Out:
#             MMM  ABT  ABBV  ABMD  ACN  ATVI  ADBE  AMD  AAP  AES  ...  WYNN  \
# Date                                                              ...
# 1962-01-02  NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN
# 1962-01-03  NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN
# 1962-01-04  NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN
# 1962-01-05  NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN
# 1962-01-08  NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN  NaN  NaN  ...   NaN
#
#             XEL  XRX  XLNX  XYL  YUM  ZBRA  ZBH  ZION  ZTS
# Date
# 1962-01-02  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN
# 1962-01-03  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN
# 1962-01-04  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN
# 1962-01-05  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN
# 1962-01-08  NaN  NaN   NaN  NaN  NaN   NaN  NaN   NaN  NaN
#
# [5 rows x 505 columns]

# %%
df_pct_change.tail()
# Out:
#                  MMM       ABT      ABBV      ABMD       ACN      ATVI  \
# Date
# 2020-08-20 -0.006093  0.011445 -0.009365 -0.013806  0.008439  0.024640
# 2020-08-21  0.001300  0.007577 -0.003571 -0.007871  0.003719 -0.009405
# 2020-08-24  0.011255 -0.009863 -0.003690 -0.008518  0.001095 -0.001322
# 2020-08-25 -0.002629  0.010652 -0.004761  0.020233  0.001935  0.006258
# 2020-08-26  0.004905  0.007026  0.003083 -0.016007  0.009403  0.010285
#
#                 ADBE       AMD       AAP       AES  ...      WYNN       XEL  \
# Date                                                ...
# 2020-08-20  0.035649  0.020718 -0.020956  0.018729  ... -0.012060 -0.008192
# 2020-08-21 -0.010993  0.012565 -0.008448  0.003900  ...  0.031266  0.008694
# 2020-08-24  0.006509 -0.008710  0.006598  0.002775  ...  0.048315  0.011493
# 2020-08-25  0.017069  0.039360 -0.006873 -0.009961  ... -0.006683 -0.020452
# 2020-08-26  0.090952 -0.003822  0.002691 -0.008944  ... -0.016355 -0.012179
#
# ...

# %% [markdown]
# # Reference
#
# [How to find Percentage Change in pandas](https://kanoki.org/2019/09/29/how-to-find-percentage-change-in-pandas/)
#
# [pandas.DataFrame.pct_change](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.pct_change.html)
