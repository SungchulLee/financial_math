# %%
import pandas as pd
tickers = pd.read_csv('../data/sp500/tickers.csv', usecols=[1])
tickers
# Out:
#         0
# 0     MMM
# 1     ABT
# 2    ABBV
# 3    ABMD
# 4     ACN
# ..    ...
# 500   YUM
# 501  ZBRA
# 502   ZBH
# 503  ZION
# 504   ZTS
#
# [505 rows x 1 columns]

# %%
tickers = list(tickers.iloc[:,0])
tickers
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BDX',
#  'BRK-B',
#  'BBY',
#  'BIO',
#  'BIIB',
#  'BLK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF-B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
#  'CNP',
#  'CTL',
# ...

# %%
import yfinance as yf
#import time
import os
tickers_len = len(tickers)
for count, ticker in enumerate(tickers):
    if not os.path.exists('../data/sp500/{}.csv'.format(ticker)):
        stock = yf.Ticker(ticker)
        data = stock.history(period='max')
        data.to_csv('../data/sp500/{}.csv'.format(ticker))
        print('{}/{} : {} Downloaded'.format(count+1, tickers_len, ticker))
        #time.sleep(0.5)
    else:
        print('{}/{} : {} Downloaded'.format(count+1, tickers_len, ticker))
# Out:
# 1/505 : MMM Downloaded
# 2/505 : ABT Downloaded
# 3/505 : ABBV Downloaded
# 4/505 : ABMD Downloaded
# 5/505 : ACN Downloaded
# 6/505 : ATVI Downloaded
# 7/505 : ADBE Downloaded
# 8/505 : AMD Downloaded
# 9/505 : AAP Downloaded
# 10/505 : AES Downloaded
# 11/505 : AFL Downloaded
# 12/505 : A Downloaded
# 13/505 : APD Downloaded
# 14/505 : AKAM Downloaded
# 15/505 : ALK Downloaded
# 16/505 : ALB Downloaded
# 17/505 : ARE Downloaded
# 18/505 : ALXN Downloaded
# 19/505 : ALGN Downloaded
# 20/505 : ALLE Downloaded
# 21/505 : LNT Downloaded
# 22/505 : ALL Downloaded
# 23/505 : GOOGL Downloaded
# 24/505 : GOOG Downloaded
# 25/505 : MO Downloaded
# 26/505 : AMZN Downloaded
# 27/505 : AMCR Downloaded
# 28/505 : AEE Downloaded
# 29/505 : AAL Downloaded
# 30/505 : AEP Downloaded
# 31/505 : AXP Downloaded
# 32/505 : AIG Downloaded
# 33/505 : AMT Downloaded
# 34/505 : AWK Downloaded
# 35/505 : AMP Downloaded
# 36/505 : ABC Downloaded
# 37/505 : AME Downloaded
# 38/505 : AMGN Downloaded
# ...

# %%
import yfinance as yf
import time
import pandas as pd
import os
tickers_len = len(tickers)
for count, ticker in enumerate(tickers):
    data = pd.read_csv('../data/sp500/{}.csv'.format(ticker))
    if data.empty:
        stock = yf.Ticker(ticker)
        data = stock.history(period='max')
        data.to_csv('../data/sp500/{}.csv'.format(ticker))
    print('{}/{} : {} Downloaded'.format(count+1, tickers_len, ticker))
# Out:
# 1/505 : MMM Downloaded
# 2/505 : ABT Downloaded
# 3/505 : ABBV Downloaded
# 4/505 : ABMD Downloaded
# 5/505 : ACN Downloaded
# 6/505 : ATVI Downloaded
# 7/505 : ADBE Downloaded
# 8/505 : AMD Downloaded
# 9/505 : AAP Downloaded
# 10/505 : AES Downloaded
# 11/505 : AFL Downloaded
# 12/505 : A Downloaded
# 13/505 : APD Downloaded
# 14/505 : AKAM Downloaded
# 15/505 : ALK Downloaded
# 16/505 : ALB Downloaded
# 17/505 : ARE Downloaded
# 18/505 : ALXN Downloaded
# 19/505 : ALGN Downloaded
# 20/505 : ALLE Downloaded
# 21/505 : LNT Downloaded
# 22/505 : ALL Downloaded
# 23/505 : GOOGL Downloaded
# 24/505 : GOOG Downloaded
# 25/505 : MO Downloaded
# 26/505 : AMZN Downloaded
# 27/505 : AMCR Downloaded
# 28/505 : AEE Downloaded
# 29/505 : AAL Downloaded
# 30/505 : AEP Downloaded
# 31/505 : AXP Downloaded
# 32/505 : AIG Downloaded
# 33/505 : AMT Downloaded
# 34/505 : AWK Downloaded
# 35/505 : AMP Downloaded
# 36/505 : ABC Downloaded
# 37/505 : AME Downloaded
# 38/505 : AMGN Downloaded
# ...

# %% [markdown]
# # Reference
#
# [How To Work with Web Data Using Requests and Beautiful Soup with Python 3](https://www.digitalocean.com/community/tutorials/how-to-work-with-web-data-using-requests-and-beautiful-soup-with-python-3)
