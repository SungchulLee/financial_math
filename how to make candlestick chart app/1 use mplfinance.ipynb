# %% [markdown]
# To install yfinance, run the following in terminal:
# ```
# $ pip install yfinance
# ```
#
# [yfinance](https://pypi.org/project/yfinance/)

# %% [markdown]
# To install mplfinance, run the following in terminal:
# ```
# $ pip install mplfinance
# ```
#
# [mplfinance](https://pypi.org/project/mplfinance/)

# %%
def draw(ticker):
    
    import yfinance as yf
    
    stock = yf.Ticker(ticker)
    df = stock.history(period='max') 
    
    import mplfinance as mpf
    
    #mc = mpf.make_marketcolors(up='tab:green', down='tab:red') # us
    mc = mpf.make_marketcolors(up='tab:red', down='tab:blue') # korea

    s = mpf.make_mpf_style(marketcolors=mc)

    mpf.plot(df[-60:],
             type="candle",
             title=ticker,
             ylabel='Stock Price',
             figratio=(12,4),
             volume=True,
             ylabel_lower='Shares\nTraded',
             show_nontrading=True,
             style=s)

# %%
ticker = '^VIX' # 변동성 지수
draw(ticker)
# Out:
# /Users/sungchullee/.local/lib/python3.7/site-packages/mplfinance/plotting.py:437: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   volumeAxes.set_ylim( miny, maxy )
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
ticker = 'VIXY' # VIX 추종
draw(ticker)
# Out:
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/sungchullee/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
ticker = 'UVXY' # VIX 추종 (x 1.5)
draw(ticker)

# %%
ticker = 'QQQ' # 나스닥 100 etf
draw(ticker)

# %%
ticker = 'PSQ' # 나스닥 인버스
draw(ticker)

# %%
ticker = 'QID' # 나스닥 인버스 (x 2)
draw(ticker)

# %%
ticker = 'SQQQ' # 나스닥 인버스 (x 3)
draw(ticker)

# %%
ticker = 'TSLA' # 테슬라
draw(ticker)

# %%
ticker = 'NIO' # 니오 (전기차)
draw(ticker)

# %%
ticker = 'SHOP' # 쇼피파이 (전자상거래)
draw(ticker)

# %%
ticker = 'NVDA' # 엔비디아
draw(ticker)

# %%
ticker = 'AAPL' # 애플
draw(ticker)

# %%
ticker = '005930.KS' # 삼성전자
draw(ticker)

# %% [markdown]
# # Reference
#
# [시장 하락 미리 알아채고 대응하는 법(변동성 지수 & 인버스 활용)](https://www.youtube.com/watch?v=jzpDZCfBSE0)
