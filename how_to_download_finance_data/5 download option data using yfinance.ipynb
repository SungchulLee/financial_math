# %%
import yfinance as yf
spy = yf.Ticker("SPY")
data = spy.option_chain('2020-08-28') # get option chain for specific expiration

# %%
type(data)
# Out:
# yfinance.ticker.Options

# %%
data
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice  bid  ask  \
# 0    SPY200828C00160000 2020-07-31 18:54:08   160.0     163.70  0.0  0.0
# 1    SPY200828C00245000 2020-08-21 17:56:22   245.0      96.93  0.0  0.0
# 2    SPY200828C00250000 2020-08-20 13:58:39   250.0      86.82  0.0  0.0
# 3    SPY200828C00255000 2020-08-04 14:01:01   255.0      73.95  0.0  0.0
# 4    SPY200828C00260000 2020-08-24 16:10:32   260.0      81.90  0.0  0.0
# ..                  ...                 ...     ...        ...  ...  ...
# 99   SPY200828C00385000 2020-08-14 14:39:06   385.0       0.01  0.0  0.0
# 100  SPY200828C00390000 2020-08-19 17:30:24   390.0       0.01  0.0  0.0
# 101  SPY200828C00395000 2020-08-13 13:46:12   395.0       0.01  0.0  0.0
# 102  SPY200828C00400000 2020-08-21 17:52:47   400.0       0.01  0.0  0.0
# 103  SPY200828C00410000 2020-08-20 16:46:39   410.0       0.01  NaN  0.0
#
#      change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
data.calls
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice  bid  ask  \
# 0    SPY200828C00160000 2020-07-31 18:54:08   160.0     163.70  0.0  0.0
# 1    SPY200828C00245000 2020-08-21 17:56:22   245.0      96.93  0.0  0.0
# 2    SPY200828C00250000 2020-08-20 13:58:39   250.0      86.82  0.0  0.0
# 3    SPY200828C00255000 2020-08-04 14:01:01   255.0      73.95  0.0  0.0
# 4    SPY200828C00260000 2020-08-24 16:10:32   260.0      81.90  0.0  0.0
# ..                  ...                 ...     ...        ...  ...  ...
# 99   SPY200828C00385000 2020-08-14 14:39:06   385.0       0.01  0.0  0.0
# 100  SPY200828C00390000 2020-08-19 17:30:24   390.0       0.01  0.0  0.0
# 101  SPY200828C00395000 2020-08-13 13:46:12   395.0       0.01  0.0  0.0
# 102  SPY200828C00400000 2020-08-21 17:52:47   400.0       0.01  0.0  0.0
# 103  SPY200828C00410000 2020-08-20 16:46:39   410.0       0.01  NaN  0.0
#
#      change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
data.puts
# Out:
#          contractSymbol       lastTradeDate  strike  lastPrice    bid    ask  \
# 0    SPY200828P00160000 2020-08-10 19:41:05   160.0       0.01   0.00   0.00
# 1    SPY200828P00165000 2020-08-10 14:08:06   165.0       0.01   0.00   0.00
# 2    SPY200828P00170000 2020-07-29 14:29:38   170.0       0.01   0.00   0.00
# 3    SPY200828P00175000 2020-08-11 20:06:35   175.0       0.01   0.00   0.00
# 4    SPY200828P00180000 2020-08-06 17:51:38   180.0       0.02   0.00   0.00
# ..                  ...                 ...     ...        ...    ...    ...
# 109  SPY200828P00375000 2020-08-17 04:06:39   375.0      38.57   0.00   0.00
# 110  SPY200828P00380000 2020-08-10 14:45:41   380.0      45.31   0.00   0.00
# 111  SPY200828P00385000 2020-07-21 18:38:20   385.0      58.60  46.69  47.01
# 112  SPY200828P00400000 2020-08-10 14:01:53   400.0      65.08   0.00   0.00
# 113  SPY200828P00410000 2020-08-24 04:09:07   410.0      72.11   0.00   0.00
#
# ...

# %% [markdown]
# # Reference
#
# [yfinance](https://pypi.org/project/yfinance/)
